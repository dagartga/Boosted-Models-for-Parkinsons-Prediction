# %%
import pandas as pd

# %%
df_1 = pd.read_csv('~/parkinsons_proj_1/parkinsons_project/parkinsons_1/models/model_results/baseline_2023-04-19_fold_results.csv')

# %%
df_1
# Out:
#       Model   Target  Fold   SMAPE        R2          MAPE
# 0    rf_reg  updrs_1     0   65.47  0.115200  1.911084e+15
# 1    rf_reg  updrs_1     1   67.22  0.181055  2.081336e+15
# 2    rf_reg  updrs_1     2   66.90  0.066543  1.311095e+15
# 3    rf_reg  updrs_1     3   64.60  0.183373  1.425083e+15
# 4    rf_reg  updrs_1     4   64.82  0.139542  1.350868e+15
# 5    rf_reg  updrs_2     0   92.63  0.132031  6.705313e+15
# 6    rf_reg  updrs_2     1   91.56  0.124037  5.685689e+15
# 7    rf_reg  updrs_2     2   94.84  0.144502  6.085331e+15
# 8    rf_reg  updrs_2     3   93.92  0.178858  5.430538e+15
# 9    rf_reg  updrs_2     4   90.19  0.172390  4.990750e+15
# 10   rf_reg  updrs_3     0   86.08  0.156046  1.452687e+16
# 11   rf_reg  updrs_3     1   84.72  0.168099  1.096903e+16
# 12   rf_reg  updrs_3     2   82.60  0.190846  1.091443e+16
# 13   rf_reg  updrs_3     3   82.65  0.250607  9.628098e+15
# 14   rf_reg  updrs_3     4   84.77  0.156421  1.397461e+16
# ...

# %%
df_2 = pd.read_csv('~/parkinsons_proj_1/parkinsons_project/parkinsons_1/models/model_results/baseline_2023-04-21_fold_results.csv')

# %%
df_2
# Out:
#       Model   Target  Fold   SMAPE        R2          MAPE
# 0    rf_reg  updrs_1     0   64.19  0.174343  1.761455e+15
# 1    rf_reg  updrs_1     1   66.29  0.245029  1.867310e+15
# 2    rf_reg  updrs_1     2   65.44  0.107973  1.371493e+15
# 3    rf_reg  updrs_1     3   64.40  0.213723  1.387447e+15
# 4    rf_reg  updrs_1     4   64.74  0.163501  1.374338e+15
# 5    rf_reg  updrs_2     0   91.21  0.157892  6.732671e+15
# 6    rf_reg  updrs_2     1   90.21  0.215001  5.273210e+15
# 7    rf_reg  updrs_2     2   93.60  0.206432  5.633498e+15
# 8    rf_reg  updrs_2     3   91.72  0.241976  5.215930e+15
# 9    rf_reg  updrs_2     4   91.04  0.204432  4.440169e+15
# 10   rf_reg  updrs_3     0   84.65  0.206157  1.441577e+16
# 11   rf_reg  updrs_3     1   83.63  0.233300  1.021956e+16
# 12   rf_reg  updrs_3     2   81.42  0.262307  1.018812e+16
# 13   rf_reg  updrs_3     3   80.26  0.292070  9.475488e+15
# 14   rf_reg  updrs_3     4   83.38  0.251424  1.288392e+16
# ...

# %%
df_3 = pd.read_csv('~/parkinsons_proj_1/parkinsons_project/parkinsons_1/models/model_results/baseline_2023-04-29_fold_results.csv')

# %%
df_3
# Out:
#       Model   Target  Fold   SMAPE        R2          MAPE
# 0    rf_reg  updrs_1     0   62.91  0.157581  1.090043e+15
# 1    rf_reg  updrs_1     1   68.26  0.135672  1.966797e+15
# 2    rf_reg  updrs_1     2   67.99  0.151110  2.297114e+15
# 3    rf_reg  updrs_1     3   64.16  0.109320  1.263407e+15
# 4    rf_reg  updrs_1     4   66.88  0.144402  1.462473e+15
# 5    rf_reg  updrs_2     0   91.66  0.194947  5.264096e+15
# 6    rf_reg  updrs_2     1   92.58  0.139231  5.979946e+15
# 7    rf_reg  updrs_2     2   92.33  0.131835  5.214573e+15
# 8    rf_reg  updrs_2     3   91.15  0.175476  5.662119e+15
# 9    rf_reg  updrs_2     4   95.61  0.160422  6.488066e+15
# 10   rf_reg  updrs_3     0   82.94  0.221026  1.151101e+16
# 11   rf_reg  updrs_3     1   82.73  0.176760  1.200220e+16
# 12   rf_reg  updrs_3     2   85.08  0.186868  1.193220e+16
# 13   rf_reg  updrs_3     3   84.51  0.185513  1.110117e+16
# 14   rf_reg  updrs_3     4   85.12  0.213193  1.406596e+16
# ...

# %%
df_4 = pd.read_csv('~/parkinsons_proj_1/parkinsons_project/parkinsons_1/models/model_results/baseline_visit0_fold_results.csv')

# %%
df_4
# Out:
#       Model   Target  Fold   SMAPE        R2          MAPE
# 0    rf_reg  updrs_1     0   64.19  0.174343  1.761455e+15
# 1    rf_reg  updrs_1     1   66.29  0.245029  1.867310e+15
# 2    rf_reg  updrs_1     2   65.44  0.107973  1.371493e+15
# 3    rf_reg  updrs_1     3   64.40  0.213723  1.387447e+15
# 4    rf_reg  updrs_1     4   64.74  0.163501  1.374338e+15
# 5    rf_reg  updrs_2     0   91.21  0.157892  6.732671e+15
# 6    rf_reg  updrs_2     1   90.21  0.215001  5.273210e+15
# 7    rf_reg  updrs_2     2   93.60  0.206432  5.633498e+15
# 8    rf_reg  updrs_2     3   91.72  0.241976  5.215930e+15
# 9    rf_reg  updrs_2     4   91.04  0.204432  4.440169e+15
# 10   rf_reg  updrs_3     0   84.65  0.206157  1.441577e+16
# 11   rf_reg  updrs_3     1   83.63  0.233300  1.021956e+16
# 12   rf_reg  updrs_3     2   81.42  0.262307  1.018812e+16
# 13   rf_reg  updrs_3     3   80.26  0.292070  9.475488e+15
# 14   rf_reg  updrs_3     4   83.38  0.251424  1.288392e+16
# ...

# %%
df_5 = pd.read_csv('~/parkinsons_proj_1/parkinsons_project/parkinsons_1/models/model_results/baseline_visit0_summary_results.csv')

# %%
df_5
# Out:
#    Unnamed: 0    Model   SMAPE
# 0           0     lgbm  96.494
# 1           1   rf_reg  97.965
# 2           2  xgboost  98.415

# %%
df_2.groupby('Model')['SMAPE'].mean()
# Out:
# Model
# lgbm       97.0775
# rf_reg     97.0160
# xgboost    98.8780
# Name: SMAPE, dtype: float64

# %%
df_1.groupby('Model')['SMAPE'].mean()
# Out:
# Model
# lgbm        98.3250
# rf_reg      98.2135
# xgboost    100.7890
# Name: SMAPE, dtype: float64

# %%
df_3.groupby('Model')['SMAPE'].mean()
# Out:
# Model
# lgbm       96.494
# rf_reg     97.965
# xgboost    98.415
# Name: SMAPE, dtype: float64

# %%
df_4.groupby('Model')['SMAPE'].mean()
# Out:
# Model
# lgbm       97.0775
# rf_reg     97.0160
# xgboost    98.8780
# Name: SMAPE, dtype: float64

# %%
df_6 = pd.read_csv('~/parkinsons_proj_1/parkinsons_project/parkinsons_1/models/model_results/rfreg_visit0_results.csv')
df_6
# Out:
#     Model   Target   SMAPE        R2          MAPE       MAE
# 0  rf_reg  updrs_1   51.56  0.613905  1.066889e+15  2.499233
# 1  rf_reg  updrs_2   79.36  0.629611  3.642276e+15  2.810415
# 2  rf_reg  updrs_3   71.56  0.639435  7.876568e+15  7.334897
# 3  rf_reg  updrs_4  137.40  0.561715  3.535162e+15  1.550618

# %%
df_6.groupby('Model')['SMAPE'].mean()
# Out:
# Model
# rf_reg    84.97
# Name: SMAPE, dtype: float64

# %%
df_7 = pd.read_csv('~/parkinsons_proj_1/parkinsons_project/parkinsons_1/models/model_results/rfreg_visit0_default_results.csv')
df_7
# Out:
#     Model   Target   SMAPE        R2          MAPE       MAE
# 0  rf_reg  updrs_1   37.31  0.882939  5.796065e+14  1.366039
# 1  rf_reg  updrs_2   67.42  0.892340  1.926933e+15  1.502659
# 2  rf_reg  updrs_3   58.82  0.897123  4.140758e+15  3.878280
# 3  rf_reg  updrs_4  129.54  0.865881  2.021159e+15  0.860422

# %%
df_7.groupby('Model')['SMAPE'].mean()
# Out:
# Model
# rf_reg    73.2725
# Name: SMAPE, dtype: float64

# %%
df_8 = pd.read_csv('~/parkinsons_proj_1/parkinsons_project/parkinsons_1/models/model_results/baseline_forecast_results.csv')
df_8.groupby('Model')['SMAPE'].mean()
# Out:
# Model
# lgbm       87.380000
# rf_reg     81.008182
# xgboost    85.327273
# Name: SMAPE, dtype: float64

# %%
df_9 = pd.read_csv('~/parkinsons_proj_1/parkinsons_project/parkinsons_1/models/model_results/rfreg_2023-05-06_forecast_results.csv')
df_9.groupby('Model')['SMAPE'].mean()
# Out:
# Model
# rf_reg    124.54
# Name: SMAPE, dtype: float64
